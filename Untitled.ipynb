# %%
from flask import render_template, redirect, Flask, jsonify
from flask_pymongo import PyMongo
import pymongo
import scrape_redfin
from config import username, password
from flask import request

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.house_app

# %%
test = []
data= db.redfin_rawdata.find()
for d in data:
    del d["_id"]
    test.append(d)

list(test)
# Out:
# [{'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '2,139 Sq. Ft.',
#   'price': '$990,000',
#   'address': '3504 Old Topanga Canyon Rd, Topanga, CA 90290',
#   'link': 'https://www.redfin.com/CA/Topanga/3504-Old-Topanga-Canyon-Rd-90290/home/3597466',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 957000),
#   'city': 'Topanga'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,180 Sq. Ft.',
#   'price': '$345,000',
#   'address': '7226 Jordan Ave #3, Canoga Park, CA 91303',
#   'link': 'https://www.redfin.com/CA/Canoga-Park/7226-Jordan-Ave-91303/unit-3/home/3730620',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 958000),
#   'city': 'Canoga Park'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '2,033 Sq. Ft.',
#   'price': '$1,099,000',
#   'address': '15220 Valleyheart Dr, Sherman Oaks, CA 91403',
#   'link': 'https://www.redfin.com/CA/Sherman-Oaks/15220-Valleyheart-Dr-91403/home/4806619',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 958000),
#   'city': 'Sherman Oaks'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '849 Sq. Ft.',
#   'price': '$359,000',
#   'address': '1207 Obispo Ave #112, Long Beach, CA 90804',
#   'link': 'https://www.redfin.com/CA/Long-Beach/1207-Obispo-Ave-90804/unit-112/home/7604672',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 959000),
#   'city': 'Long Beach'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '2,525 Sq. Ft.',
#   'price': '$850,000',
#   'address': '4418 Spencer St, Torrance, CA 90503',
#   'link': 'https://www.redfin.com/CA/Torrance/4418-Spencer-St-90503/home/7715714',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 959000),
#   'city': 'Torrance'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,091 Sq. Ft.',
#   'price': '$769,988',
#   'address': '759 Bowcreek Dr, Diamond Bar, CA 91765',
#   'link': 'https://www.redfin.com/CA/Diamond-Bar/759-Bowcreek-Dr-91765/home/7874893',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 960000),
#   'city': 'Diamond Bar'},
#  {'beds': '3 Beds',
#   'baths': '1.75 Baths',
#   'area': '1,352 Sq. Ft.',
#   'price': '$649,000',
#   'address': '825 Edie Dr, Duarte, CA 91010',
#   'link': 'https://www.redfin.com/CA/Duarte/825-Edie-Dr-91010/home/8013692',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 960000),
#   'city': 'Duarte'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '850 Sq. Ft.',
#   'price': '$349,990',
#   'address': '3516 E Ransom St #203, Long Beach, CA 90804',
#   'link': 'https://www.redfin.com/CA/Long-Beach/3516-E-Ransom-St-90804/unit-203/home/8182193',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 961000),
#   'city': 'Long Beach'},
#  {'beds': '5 Beds',
#   'baths': '3 Baths',
#   'area': '1,938 Sq. Ft.',
#   'price': '$765,000',
#   'address': '23728 Maidstone Pl, Harbor City, CA 90710',
#   'link': 'https://www.redfin.com/CA/Harbor-City/23728-Maidstone-Pl-90710/home/7682313',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 962000),
#   'city': 'Harbor City'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '619 Sq. Ft.',
#   'price': '$280,000',
#   'address': '19350 Sherman Way #327, Reseda, CA 91335',
#   'link': 'https://www.redfin.com/CA/Reseda/19350-Sherman-Way-91335/unit-327/home/3895379',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 963000),
#   'city': 'Reseda'},
#  {'beds': '3 Beds',
#   'baths': '1 Bath',
#   'area': '1,352 Sq. Ft.',
#   'price': '$649,000',
#   'address': '17610 Blythe St, Northridge, CA 91325',
#   'link': 'https://www.redfin.com/CA/Northridge/17610-Blythe-St-91325/home/4322974',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 963000),
#   'city': 'Northridge'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '2,945 Sq. Ft.',
#   'price': '$995,000',
#   'address': '2140 Stanley Ave, Signal Hill, CA 90755',
#   'link': 'https://www.redfin.com/CA/Signal-Hill/2140-Stanley-Ave-90755/home/8143754',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 964000),
#   'city': 'Signal Hill'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,427 Sq. Ft.',
#   'price': '$503,000',
#   'address': '15160 Rayen St, North Hills, CA 91343',
#   'link': 'https://www.redfin.com/CA/North-Hills/15160-Rayen-St-91343/home/17234684',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 964000),
#   'city': 'North Hills'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,283 Sq. Ft.',
#   'price': '$709,998',
#   'address': '19 Old Wood Rd, Phillips Ranch, CA 91766',
#   'link': 'https://www.redfin.com/CA/Pomona/19-Old-Wood-Rd-91766/home/8061335',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 965000),
#   'city': 'Phillips Ranch'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,300 Sq. Ft.',
#   'price': '$549,000',
#   'address': '13331 Moorpark St #337, Sherman Oaks, CA 91423',
#   'link': 'https://www.redfin.com/CA/Sherman-Oaks/13331-Moorpark-St-91423/unit-337/home/5219900',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 965000),
#   'city': 'Sherman Oaks'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '951 Sq. Ft.',
#   'price': '$410,000',
#   'address': '535 W 4th St #109, Long Beach, CA 90802',
#   'link': 'https://www.redfin.com/CA/Long-Beach/535-W-4th-St-90802/unit-109/home/7620149',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 966000),
#   'city': 'Long Beach'},
#  {'beds': '3 Beds',
#   'baths': '1.75 Baths',
#   'area': '958 Sq. Ft.',
#   'price': '$545,000',
#   'address': '7714 La Salle Ave, Los Angeles, CA 90047',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/7714-La-Salle-Ave-90047/home/7281998',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 966000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3.5 Baths',
#   'area': '2,950 Sq. Ft.',
#   'price': '$949,000',
#   'address': '4308 Spencer St, Torrance, CA 90503',
#   'link': 'https://www.redfin.com/CA/Torrance/4308-Spencer-St-90503/home/7715802',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 967000),
#   'city': 'Torrance'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,070 Sq. Ft.',
#   'price': '$580,000',
#   'address': '11306 Moorpark St #9, Studio City, CA 91602',
#   'link': 'https://www.redfin.com/CA/North-Hollywood/11306-Moorpark-St-91602/unit-9/home/5230769',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 967000),
#   'city': 'Studio City'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '948 Sq. Ft.',
#   'price': '$799,000',
#   'address': '4860 Westhaven St, Los Angeles, CA 90016',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/4860-Westhaven-St-90016/home/6897755',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 968000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,075 Sq. Ft.',
#   'price': '$739,000',
#   'address': '1441 Federal Ave #202, Los Angeles, CA 90025',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1441-Federal-Ave-90025/unit-202/home/6759391',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 52, 968000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,075 Sq. Ft.',
#   'price': '$739,000',
#   'address': '1441 Federal Ave #202, Los Angeles, CA 90025',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1441-Federal-Ave-90025/unit-202/home/6759391',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 206000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,711 Sq. Ft.',
#   'price': '$1,249,000',
#   'address': '1911 Pinehurst Rd, Los Angeles, CA 90068',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1911-Pinehurst-Rd-90068/home/28913050',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 206000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '2,147 Sq. Ft.',
#   'price': '$1,125,000',
#   'address': '9132 Broadway, Temple City, CA 91780',
#   'link': 'https://www.redfin.com/CA/Temple-City/9132-Broadway-91780/home/7048711',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 207000),
#   'city': 'Temple City'},
#  {'beds': '4 Beds',
#   'baths': '3.5 Baths',
#   'area': '2,649 Sq. Ft.',
#   'price': '$1,199,000',
#   'address': '2020 Farrell Ave #3, Redondo Beach, CA 90278',
#   'link': 'https://www.redfin.com/CA/Redondo-Beach/2020-Farrell-Ave-90278/unit-3/home/6678913',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 208000),
#   'city': 'Redondo Beach'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,320 Sq. Ft.',
#   'price': '$845,000',
#   'address': '1444 S Point View St #302, Los Angeles, CA 90035',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1444-S-Point-View-St-90035/unit-302/home/17229397',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 209000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,395 Sq. Ft.',
#   'price': '$569,000',
#   'address': '551 Linwood Ave Unit G, Monrovia, CA 91016',
#   'link': 'https://www.redfin.com/CA/Monrovia/551-Linwood-Ave-91016/unit-G/home/7965150',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 209000),
#   'city': 'Monrovia'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,586 Sq. Ft.',
#   'price': '$478,000',
#   'address': '15050 Sherman Way #233, Van Nuys, CA 91405',
#   'link': 'https://www.redfin.com/CA/Van-Nuys/15050-Sherman-Way-91405/unit-233/home/4460668',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 210000),
#   'city': 'Van Nuys'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,107 Sq. Ft.',
#   'price': '$615,000',
#   'address': '413 S Glendora Ave, Glendora, CA 91741',
#   'link': 'https://www.redfin.com/CA/Glendora/413-S-Glendora-Ave-91741/home/51587557',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 210000),
#   'city': 'Glendora'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '693 Sq. Ft.',
#   'price': '$389,900',
#   'address': '564 N Bellflower Blvd #104, Long Beach, CA 90814',
#   'link': 'https://www.redfin.com/CA/Long-Beach/564-N-Bellflower-Blvd-90814/unit-104/home/7595246',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 211000),
#   'city': 'Long Beach'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '2,436 Sq. Ft.',
#   'price': '$1,198,000',
#   'address': '4426 San Andreas Ave, Los Angeles, CA 90065',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/4426-San-Andreas-Ave-90065/home/7078233',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 212000),
#   'city': 'Los Angeles'},
#  {'beds': '4 Beds',
#   'baths': '2 Baths',
#   'area': '1,920 Sq. Ft.',
#   'price': '$664,900',
#   'address': '1515 Temple Ave, Long Beach, CA 90804',
#   'link': 'https://www.redfin.com/CA/Long-Beach/1515-Temple-Ave-90804/home/7605308',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 213000),
#   'city': 'Long Beach'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,523 Sq. Ft.',
#   'price': '$465,000',
#   'address': '17510 Sherman Way #111, Lake Balboa, CA 91406',
#   'link': 'https://www.redfin.com/CA/Van-Nuys/17510-Sherman-Way-91406/unit-111/home/4534880',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 213000),
#   'city': 'Lake Balboa'},
#  {'beds': '4 Beds',
#   'baths': '4 Baths',
#   'area': '3,042 Sq. Ft.',
#   'price': '$898,000',
#   'address': '20135 Donway Dr, Walnut, CA 91789',
#   'link': 'https://www.redfin.com/CA/Walnut/20135-Donway-Dr-91789/home/8088170',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 214000),
#   'city': 'Walnut'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '536 Sq. Ft.',
#   'price': '$649,000',
#   'address': '1319 11th St #5, Santa Monica, CA 90401',
#   'link': 'https://www.redfin.com/CA/Santa-Monica/1319-11th-St-90401/unit-5/home/6774034',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 214000),
#   'city': 'Santa Monica'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '728 Sq. Ft.',
#   'price': '$949,999',
#   'address': '1320 Gates Pl, South Pasadena, CA 91030',
#   'link': 'https://www.redfin.com/CA/South-Pasadena/1320-Gates-Pl-91030/home/7004804',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 215000),
#   'city': 'South Pasadena'},
#  {'beds': '2 Beds',
#   'baths': '1.75 Baths',
#   'area': '980 Sq. Ft.',
#   'price': '$734,990',
#   'address': '2916 E Colorado St, Long Beach, CA 90814',
#   'link': 'https://www.redfin.com/CA/Long-Beach/2916-E-Colorado-St-90814/home/7603085',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 215000),
#   'city': 'Long Beach'},
#  {'beds': '6 Beds',
#   'baths': '3 Baths',
#   'area': '3,080 Sq. Ft.',
#   'price': '$960,000',
#   'address': '4252 Emerald Cir, Cypress, CA 90630',
#   'link': 'https://www.redfin.com/CA/Cypress/4252-Emerald-Cir-90630/home/4015441',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 216000),
#   'city': 'Cypress'},
#  {'beds': '1 Bed',
#   'baths': '0.75 Baths',
#   'area': '491 Sq. Ft.',
#   'price': '$499,000',
#   'address': '284 Vista Circle Dr, Sierra Madre, CA 91024',
#   'link': 'https://www.redfin.com/CA/Sierra-Madre/284-Vista-Cir-Dr-91024/home/7225677',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 216000),
#   'city': 'Sierra Madre'},
#  {'beds': '2 Beds',
#   'baths': '2.5 Baths',
#   'area': '1,420 Sq. Ft.',
#   'price': '$1,299,000',
#   'address': '848 Lincoln Blvd Unit A, Santa Monica, CA 90403',
#   'link': 'https://www.redfin.com/CA/Santa-Monica/848-Lincoln-Blvd-90403/unit-A/home/6780004',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 217000),
#   'city': 'Santa Monica'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '870 Sq. Ft.',
#   'price': '$425,000',
#   'address': '2001 Artesia Blvd #202, Redondo Beach, CA 90278',
#   'link': 'https://www.redfin.com/CA/Redondo-Beach/2001-Artesia-Blvd-90278/unit-202/home/21918160',
#   'time': datetime.datetime(2020, 7, 21, 4, 29, 59, 217000),
#   'city': 'Redondo Beach'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '812 Sq. Ft.',
#   'price': '$723,990',
#   'address': '4411 Los Feliz Blvd #605, Los Angeles, CA 90027',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/4411-Los-Feliz-Blvd-90027/unit-605/home/7133042',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 893000),
#   'city': 'Los Angeles'},
#  {'beds': '5 Beds',
#   'baths': '5.5 Baths',
#   'area': '5,325 Sq. Ft.',
#   'price': '$5,869,000',
#   'address': '5620 Villa Mar Pl, Malibu, CA 90265',
#   'link': 'https://www.redfin.com/CA/Malibu/Unknown-Unknown/home/22698554',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 895000),
#   'city': 'Malibu'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '3,219 Sq. Ft.',
#   'price': '$899,000',
#   'address': '4647 Ensenada Dr, Woodland Hills, CA 91364',
#   'link': 'https://www.redfin.com/CA/Woodland-Hills/4647-Ensenada-Dr-91364/home/4204598',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 895000),
#   'city': 'Woodland Hills'},
#  {'beds': '3 Beds',
#   'baths': '1.75 Baths',
#   'area': '1,865 Sq. Ft.',
#   'price': '$1,279,000',
#   'address': '2072 Hilldale Dr, La Canada Flintridge, CA 91011',
#   'link': 'https://www.redfin.com/CA/La-Canada-Flintridge/2072-Hilldale-Dr-91011/home/7244439',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 896000),
#   'city': 'La Canada Flintridge'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,054 Sq. Ft.',
#   'price': '$749,000',
#   'address': '6514 Coldwater Canyon Ave, Valley Glen, CA 91606',
#   'link': 'https://www.redfin.com/CA/North-Hollywood/6514-Coldwater-Canyon-Ave-91606/home/5071571',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 897000),
#   'city': 'Valley Glen'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '934 Sq. Ft.',
#   'price': '$625,000',
#   'address': '627 Deep Valley Dr #102, Rolling Hills Estates, CA 90274',
#   'link': 'https://www.redfin.com/CA/Rolling-Hills-Estates/627-Deep-Valley-Dr-90274/unit-102/home/167692023',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 898000),
#   'city': 'Rolling Hills Estates'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,329 Sq. Ft.',
#   'price': '$1,849,000',
#   'address': '3619 N Poinsettia Ave, Manhattan Beach, CA 90266',
#   'link': 'https://www.redfin.com/CA/Manhattan-Beach/3619-N-Poinsettia-Ave-90266/home/6707894',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 898000),
#   'city': 'Manhattan Beach'},
#  {'beds': '4 Beds',
#   'baths': '4 Baths',
#   'area': '2,966 Sq. Ft.',
#   'price': '$875,000',
#   'address': '23825 Bella Vista Dr, Newhall, CA 91321',
#   'link': 'https://www.redfin.com/CA/Santa-Clarita/23825-Bella-Vista-Dr-91321/home/6004542',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 899000),
#   'city': 'Newhall'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '1,867 Sq. Ft.',
#   'price': '$1,649,000',
#   'address': '12631 Rubens Ave, Los Angeles, CA 90066',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/12631-Rubens-Ave-90066/home/6732287',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 900000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '816 Sq. Ft.',
#   'price': '$669,000',
#   'address': '3515 W Alameda Ave, Burbank, CA 91505',
#   'link': 'https://www.redfin.com/CA/Burbank/3515-W-Alameda-Ave-91505/home/5392661',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 900000),
#   'city': 'Burbank'},
#  {'beds': '2 Beds',
#   'baths': '1.5 Baths',
#   'area': '1,113 Sq. Ft.',
#   'price': '$979,000',
#   'address': '1205 E Tujunga Ave, Burbank, CA 91501',
#   'link': 'https://www.redfin.com/CA/Burbank/1205-E-Tujunga-Ave-91501/home/7141016',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 901000),
#   'city': 'Burbank'},
#  {'beds': '4 Beds',
#   'baths': '2 Baths',
#   'area': '3,242 Sq. Ft.',
#   'price': '$1,375,000',
#   'address': '5063 Edgewood Pl, Los Angeles, CA 90019',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/5063-Edgewood-Pl-90019/home/6912462',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 901000),
#   'city': 'Los Angeles'},
#  {'beds': '4 Beds',
#   'baths': '2 Baths',
#   'area': '1,976 Sq. Ft.',
#   'price': '$925,000',
#   'address': '4756 Larkwood Ave, Woodland Hills, CA 91364',
#   'link': 'https://www.redfin.com/CA/Woodland-Hills/4756-Larkwood-Ave-91364/home/3549058',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 902000),
#   'city': 'Woodland Hills'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,464 Sq. Ft.',
#   'price': '$729,000',
#   'address': '515 Meyer Ln #29, Redondo Beach, CA 90278',
#   'link': 'https://www.redfin.com/CA/Redondo-Beach/515-Meyer-Ln-90278/unit-29/home/6698993',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 902000),
#   'city': 'Redondo Beach'},
#  {'beds': '5 Beds',
#   'baths': '3.5 Baths',
#   'area': '3,677 Sq. Ft.',
#   'price': '$4,399,000',
#   'address': '643 Radcliffe Ave, Pacific Palisades, CA 90272',
#   'link': 'https://www.redfin.com/CA/Pacific-Palisades/643-Radcliffe-Ave-90272/home/6841629',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 903000),
#   'city': 'Pacific Palisades'},
#  {'beds': '6 Beds',
#   'baths': '4 Baths',
#   'area': '3,138 Sq. Ft.',
#   'price': '$1,400,000',
#   'address': '5444 Alvern Cir, Los Angeles, CA 90045',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/5444-Alvern-Cir-90045/home/6599441',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 903000),
#   'city': 'Los Angeles'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '735 Sq. Ft.',
#   'price': '$510,000',
#   'address': '100 S Alameda St #214, Los Angeles, CA 90012',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/100-S-Alameda-St-90012/unit-214/home/17235417',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 904000),
#   'city': 'Los Angeles'},
#  {'beds': '4 Beds',
#   'baths': '3.5 Baths',
#   'area': '2,234 Sq. Ft.',
#   'price': '$1,430,000',
#   'address': '1911 Manning Ave #2, Los Angeles, CA 90025',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1911-Manning-Ave-90025/unit-2/home/6799781',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 904000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '2.5 Baths',
#   'area': '2,246 Sq. Ft.',
#   'price': '$3,749,000',
#   'address': '801 Stanford St, Santa Monica, CA 90403',
#   'link': 'https://www.redfin.com/CA/Santa-Monica/801-Stanford-St-90403/home/6762314',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 905000),
#   'city': 'Santa Monica'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,498 Sq. Ft.',
#   'price': '$559,000',
#   'address': '7246 N Cherry Ln, Van Nuys, CA 91405',
#   'link': 'https://www.redfin.com/CA/Van-Nuys/7246-Cherry-Ln-91405/home/109716997',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 905000),
#   'city': 'Van Nuys'},
#  {'beds': '—Beds',
#   'baths': '—Baths',
#   'area': '—Sq. Ft.',
#   'price': '$200,000',
#   'address': '4291 Scandia Way, Los Angeles, CA 90065',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/4291-Scandia-Way-90065/home/23151322',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 9, 906000),
#   'city': 'Los Angeles'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '3,038 Sq. Ft.',
#   'price': '$2,600,000',
#   'address': '28500 E Palos Verdes Dr, Rancho Palos Verdes, CA 90275',
#   'link': 'https://www.redfin.com/CA/Rancho-Palos-Verdes/28500-Palos-Verdes-Dr-E-90275/home/7732651',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 102000),
#   'city': 'Rancho Palos Verdes'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '693 Sq. Ft.',
#   'price': '$325,000',
#   'address': '24123 Del Monte Dr #97, Valencia, CA 91355',
#   'link': 'https://www.redfin.com/CA/Santa-Clarita/24123-W-Del-Monte-Dr-91355/unit-97/home/6074750',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 102000),
#   'city': 'Valencia'},
#  {'beds': '5 Beds',
#   'baths': '5 Baths',
#   'area': '4,359 Sq. Ft.',
#   'price': '$1,824,999',
#   'address': '2954 Zane Grey, Altadena, CA 91001',
#   'link': 'https://www.redfin.com/CA/Altadena/2954-Zane-Grey-Ter-91001/home/7259675',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 103000),
#   'city': 'Altadena'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,399 Sq. Ft.',
#   'price': '$699,999',
#   'address': '11505 Amalfi Way, Northridge, CA 91326',
#   'link': 'https://www.redfin.com/CA/Porter-Ranch/11505-Amalfi-Way-91326/home/51576125',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 104000),
#   'city': 'Northridge'},
#  {'beds': '8 Beds',
#   'baths': '4 Baths',
#   'area': '4,892 Sq. Ft.',
#   'price': '$1,749,000',
#   'address': '4546 St Elmo Dr, Los Angeles, CA 90019',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/4546-St-Elmo-Dr-90019/home/6905933',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 104000),
#   'city': 'Los Angeles'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,043 Sq. Ft.',
#   'price': '$749,000',
#   'address': '1259 N Deborah Ave, Azusa, CA 91702',
#   'link': 'https://www.redfin.com/CA/Azusa/1259-N-Deborah-Ave-91702/home/8020058',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 105000),
#   'city': 'Azusa'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,700 Sq. Ft.',
#   'price': '$775,000',
#   'address': '2440 Marber Ave, Long Beach, CA 90815',
#   'link': 'https://www.redfin.com/CA/Long-Beach/2440-Marber-Ave-90815/home/7581463',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 105000),
#   'city': 'Long Beach'},
#  {'beds': '3 Beds',
#   'baths': '3.25 Baths',
#   'area': '2,455 Sq. Ft.',
#   'price': '$1,425,000',
#   'address': '2437 San Pasqual St, Pasadena, CA 91107',
#   'link': 'https://www.redfin.com/CA/Pasadena/2437-San-Pasqual-St-91107/home/7013833',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 106000),
#   'city': 'Pasadena'},
#  {'beds': '2 Beds',
#   'baths': '2.5 Baths',
#   'area': '1,100 Sq. Ft.',
#   'price': '$845,000',
#   'address': '11949 Goshen Ave #102, Los Angeles, CA 90049',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/11949-Goshen-Ave-90049/unit-102/home/6761478',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 106000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,950 Sq. Ft.',
#   'price': '$1,099,000',
#   'address': '1910 Bonita Ave, Burbank, CA 91504',
#   'link': 'https://www.redfin.com/CA/Burbank/1910-Bonita-Ave-91504/home/5364807',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 107000),
#   'city': 'Burbank'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,368 Sq. Ft.',
#   'price': '$474,900',
#   'address': '3595 Santa Fe Ave #151, Long Beach, CA 90810',
#   'link': 'https://www.redfin.com/CA/Long-Beach/3595-Santa-Fe-Ave-90810/unit-151/home/22954358',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 107000),
#   'city': 'Long Beach'},
#  {'beds': '4 Beds',
#   'baths': '4 Baths',
#   'area': '2,120 Sq. Ft.',
#   'price': '$2,129,000',
#   'address': '836 Bard St, Hermosa Beach, CA 90254',
#   'link': 'https://www.redfin.com/CA/Hermosa-Beach/836-Bard-St-90254/home/6717141',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 108000),
#   'city': 'Hermosa Beach'},
#  {'beds': '1 Bed',
#   'baths': '2 Baths',
#   'area': '900 Sq. Ft.',
#   'price': '$449,000',
#   'address': '210 N Monterey St #202, Alhambra, CA 91801',
#   'link': 'https://www.redfin.com/CA/Alhambra/210-N-Monterey-St-91801/unit-202/home/102235909',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 108000),
#   'city': 'Alhambra'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '760 Sq. Ft.',
#   'price': '$739,000',
#   'address': '889 Francisco St #1010, Los Angeles, CA 90017',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/889-Francisco-St-90017/unit-1010/home/143519346',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 109000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,050 Sq. Ft.',
#   'price': '$429,000',
#   'address': '6525 Woodman Ave #30, Valley Glen, CA 91401',
#   'link': 'https://www.redfin.com/CA/Van-Nuys/6525-Woodman-Ave-91401/unit-30/home/12286449',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 109000),
#   'city': 'Valley Glen'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,314 Sq. Ft.',
#   'price': '$615,000',
#   'address': '2518 Earl Ave, Long Beach, CA 90806',
#   'link': 'https://www.redfin.com/CA/Long-Beach/2518-Earl-Ave-90806/home/7571631',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 110000),
#   'city': 'Long Beach'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,082 Sq. Ft.',
#   'price': '$575,000',
#   'address': '5317 2nd Ave, Los Angeles, CA 90043',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/5317-2nd-Ave-90043/home/6863823',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 110000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '2,200 Sq. Ft.',
#   'price': '$1,298,000',
#   'address': '12243 45 Collins St, Valley Village, CA 91607',
#   'link': 'https://www.redfin.com/CA/North-Hollywood/12243-Collins-St-91607/home/5167728',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 111000),
#   'city': 'Valley Village'},
#  {'beds': '5 Beds',
#   'baths': '3 Baths',
#   'area': '1,584 Sq. Ft.',
#   'price': '$899,000',
#   'address': '2135 S Palm Grove Ave, Los Angeles, CA 90016',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/2135-S-Palm-Grove-Ave-90016/home/6899574',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 112000),
#   'city': 'Los Angeles'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '3,093 Sq. Ft.',
#   'price': '$1,199,900',
#   'address': '13534 Darvalle St, Cerritos, CA 90703',
#   'link': 'https://www.redfin.com/CA/Cerritos/13534-Darvalle-St-90703/home/7467276',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 112000),
#   'city': 'Cerritos'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,600 Sq. Ft.',
#   'price': '$899,000',
#   'address': '611 N Bronson Ave #9, Los Angeles, CA 90004',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/611-N-Bronson-Ave-90004/unit-9/home/17227519',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 16, 113000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '2,200 Sq. Ft.',
#   'price': '$1,298,000',
#   'address': '12243 45 Collins St, Valley Village, CA 91607',
#   'link': 'https://www.redfin.com/CA/North-Hollywood/12243-Collins-St-91607/home/5167728',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 621000),
#   'city': 'Valley Village'},
#  {'beds': '5 Beds',
#   'baths': '3 Baths',
#   'area': '1,584 Sq. Ft.',
#   'price': '$899,000',
#   'address': '2135 S Palm Grove Ave, Los Angeles, CA 90016',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/2135-S-Palm-Grove-Ave-90016/home/6899574',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 621000),
#   'city': 'Los Angeles'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '3,093 Sq. Ft.',
#   'price': '$1,199,900',
#   'address': '13534 Darvalle St, Cerritos, CA 90703',
#   'link': 'https://www.redfin.com/CA/Cerritos/13534-Darvalle-St-90703/home/7467276',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 622000),
#   'city': 'Cerritos'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,600 Sq. Ft.',
#   'price': '$899,000',
#   'address': '611 N Bronson Ave #9, Los Angeles, CA 90004',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/611-N-Bronson-Ave-90004/unit-9/home/17227519',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 622000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '792 Sq. Ft.',
#   'price': '$699,000',
#   'address': '422 S Benton Way, Los Angeles, CA 90057',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/422-S-Benton-Way-90057/home/6935216',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 623000),
#   'city': 'Los Angeles'},
#  {'beds': '6 Beds',
#   'baths': '3 Baths',
#   'area': '2,040 Sq. Ft.',
#   'price': '$798,000',
#   'address': '6348 Pickering Ave, Whittier, CA 90601',
#   'link': 'https://www.redfin.com/CA/Whittier/6348-Pickering-Ave-90601/home/7810576',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 623000),
#   'city': 'Whittier'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '2,901 Sq. Ft.',
#   'price': '$1,849,000',
#   'address': '6372 W 82nd St, Los Angeles, CA 90045',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/6372-W-82nd-St-90045/home/6611959',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 624000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '1.5 Baths',
#   'area': '1,373 Sq. Ft.',
#   'price': '$519,900',
#   'address': '1602 N San Antonio Ave, Pomona, CA 91767',
#   'link': 'https://www.redfin.com/CA/Pomona/1602-N-San-Antonio-Ave-91767/home/7891372',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 624000),
#   'city': 'Pomona'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,612 Sq. Ft.',
#   'price': '$849,000',
#   'address': '2701 Maine Ave, Long Beach, CA 90806',
#   'link': 'https://www.redfin.com/CA/Long-Beach/2701-Maine-Ave-90806/home/7567572',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 625000),
#   'city': 'Long Beach'},
#  {'beds': '4 Beds',
#   'baths': '3.5 Baths',
#   'area': '2,788 Sq. Ft.',
#   'price': '$1,999,990',
#   'address': '12437 Hortense St, Studio City, CA 91604',
#   'link': 'https://www.redfin.com/CA/Studio-City/12437-Hortense-St-91604/home/5223242',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 626000),
#   'city': 'Studio City'},
#  {'beds': '3 Beds',
#   'baths': '3.5 Baths',
#   'area': '1,920 Sq. Ft.',
#   'price': '$2,999,000',
#   'address': '124 38th Pl, Manhattan Beach, CA 90266',
#   'link': 'https://www.redfin.com/CA/Manhattan-Beach/124-38th-Pl-90266/home/6656735',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 626000),
#   'city': 'Manhattan Beach'},
#  {'beds': '3 Beds',
#   'baths': '1.75 Baths',
#   'area': '1,582 Sq. Ft.',
#   'price': '$825,000',
#   'address': '420 N Hanford, San Pedro, CA 90732',
#   'link': 'https://www.redfin.com/CA/San-Pedro/420-N-Hanford-Ave-90732/home/7687091',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 627000),
#   'city': 'San Pedro'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,043 Sq. Ft.',
#   'price': '$549,000',
#   'address': '230 Bethany Rd #108, Burbank, CA 91504',
#   'link': 'https://www.redfin.com/CA/Burbank/230-Bethany-Rd-91504/unit-108/home/5355204',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 627000),
#   'city': 'Burbank'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,587 Sq. Ft.',
#   'price': '$1,157,000',
#   'address': '4563 Inglewood Blvd, Los Angeles, CA 90230',
#   'link': 'https://www.redfin.com/CA/Culver-City/4563-Inglewood-Blvd-90230/home/6730626',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 628000),
#   'city': 'Los Angeles'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '2,877 Sq. Ft.',
#   'price': '$1,650,000',
#   'address': '5018 Sanlo Pl, Woodland Hills, CA 91364',
#   'link': 'https://www.redfin.com/CA/Woodland-Hills/5018-Sanlo-Pl-91364/home/4162407',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 628000),
#   'city': 'Woodland Hills'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,191 Sq. Ft.',
#   'price': '$560,000',
#   'address': '2417 Bloomdale St, Duarte, CA 91010',
#   'link': 'https://www.redfin.com/CA/Duarte/2417-Bloomdale-St-91010/home/8014002',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 629000),
#   'city': 'Duarte'},
#  {'beds': '4 Beds',
#   'baths': '2 Baths',
#   'area': '1,774 Sq. Ft.',
#   'price': '$1,150,000',
#   'address': '5338 Don Pio Dr Dr, Woodland Hills, CA 91364',
#   'link': 'https://www.redfin.com/CA/Woodland-Hills/5338-Don-Pio-Dr-91364/home/4185274',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 629000),
#   'city': 'Woodland Hills'},
#  {'beds': '3 Beds',
#   'baths': '2.75 Baths',
#   'area': '1,982 Sq. Ft.',
#   'price': '$1,395,000',
#   'address': '3920 Starland Dr, La Canada Flintridge, CA 91011',
#   'link': 'https://www.redfin.com/CA/La-Canada-Flintridge/3920-Starland-Dr-91011/home/7167051',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 630000),
#   'city': 'La Canada Flintridge'},
#  {'beds': '1 Bed',
#   'baths': '1.75 Baths',
#   'area': '1,117 Sq. Ft.',
#   'price': '$440,000',
#   'address': '22883 #B Nadine Cir, Torrance, CA 90505',
#   'link': 'https://www.redfin.com/CA/Torrance/22883-Nadine-Cir-90505/unit-B/home/7658598',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 630000),
#   'city': 'Torrance'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,392 Sq. Ft.',
#   'price': '$419,900',
#   'address': '27518 Jasper Way, Castaic, CA 91384',
#   'link': 'https://www.redfin.com/CA/Castaic/27518-Jasper-Way-91384/home/6083676',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 22, 631000),
#   'city': 'Castaic'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '2,100 Sq. Ft.',
#   'price': '$699,000',
#   'address': '18333 Lancaster Rd, Lancaster, CA 93536',
#   'link': 'https://www.redfin.com/CA/Lancaster/18333-Lancaster-Rd-93536/home/6373805',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 382000),
#   'city': 'Lancaster'},
#  {'beds': '5 Beds',
#   'baths': '3 Baths',
#   'area': '1,606 Sq. Ft.',
#   'price': '$525,000',
#   'address': '13815 Cagliero St, La Puente, CA 91746',
#   'link': 'https://www.redfin.com/CA/La-Puente/13815-Cagliero-St-91746/home/7994495',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 383000),
#   'city': 'La Puente'},
#  {'beds': '4 Beds',
#   'baths': '4 Baths',
#   'area': '2,431 Sq. Ft.',
#   'price': '$925,000',
#   'address': '10128 Babbitt Ave, Northridge, CA 91325',
#   'link': 'https://www.redfin.com/CA/Northridge/10128-Babbitt-Ave-91325/home/5754877',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 384000),
#   'city': 'Northridge'},
#  {'beds': '—Beds',
#   'baths': '—Baths',
#   'area': '—Sq. Ft.',
#   'price': '$49,000',
#   'address': '0 Vac/Ave V10 Drt /Vic 126 Ste, Pearblossom, CA 93553',
#   'link': 'https://www.redfin.com/CA/Pearblossom/Ave-V-10-93553/home/22618595',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 385000),
#   'city': 'Pearblossom'},
#  {'beds': '4 Beds',
#   'baths': '2.5 Baths',
#   'area': '2,287 Sq. Ft.',
#   'price': '$465,000',
#   'address': '3520 Emerald Ct, Palmdale, CA 93551',
#   'link': 'https://www.redfin.com/CA/Palmdale/3520-Emerald-Ct-93551/home/6112534',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 385000),
#   'city': 'Palmdale'},
#  {'beds': '3 Beds',
#   'baths': '1 Bath',
#   'area': '1,323 Sq. Ft.',
#   'price': '$699,000',
#   'address': '10938 Nettleton St, Sun Valley, CA 91352',
#   'link': 'https://www.redfin.com/CA/Sun-Valley/10938-Nettleton-St-91352/home/5277710',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 386000),
#   'city': 'Sun Valley'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '1,989 Sq. Ft.',
#   'price': '$1,299,000',
#   'address': '4404 Gloria Ave, Encino, CA 91436',
#   'link': 'https://www.redfin.com/CA/Encino/4404-Gloria-Ave-91436/home/4908097',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 387000),
#   'city': 'Encino'},
#  {'beds': '5 Beds',
#   'baths': '3.75 Baths',
#   'area': '2,716 Sq. Ft.',
#   'price': '$1,899,000',
#   'address': '815 Oakwood Pl, Pasadena, CA 91106',
#   'link': 'https://www.redfin.com/CA/Pasadena/815-Oakwood-Pl-91106/home/7189545',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 388000),
#   'city': 'Pasadena'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '700 Sq. Ft.',
#   'price': '$449,900',
#   'address': '434 W Cressey St, Compton, CA 90222',
#   'link': 'https://www.redfin.com/CA/Compton/434-W-Cressey-St-90222/home/7349000',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 388000),
#   'city': 'Compton'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,110 Sq. Ft.',
#   'price': '$689,000',
#   'address': '12629 Caswell Ave Unit A1, Los Angeles, CA 90066',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/12629-Caswell-Ave-90066/unit-A1/home/6739350',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 389000),
#   'city': 'Los Angeles'},
#  {'beds': '5 Beds',
#   'baths': '2 Baths',
#   'area': '1,498 Sq. Ft.',
#   'price': '$305,000',
#   'address': '38446 Carolside Ave, Palmdale, CA 93550',
#   'link': 'https://www.redfin.com/CA/Palmdale/38446-Carolside-Ave-93550/home/6130959',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 390000),
#   'city': 'Palmdale'},
#  {'beds': '5 Beds',
#   'baths': '3 Baths',
#   'area': '3,186 Sq. Ft.',
#   'price': '$479,000',
#   'address': '6518 Smoketree Cir, Lancaster, CA 93536',
#   'link': 'https://www.redfin.com/CA/Lancaster/6518-Smoketree-Cir-93536/home/6360439',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 390000),
#   'city': 'Lancaster'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '2,110 Sq. Ft.',
#   'price': '$4,650,000',
#   'address': '21605 Rambla Vis, Malibu, CA 90265',
#   'link': 'https://www.redfin.com/CA/Malibu/21605-Rambla-Vis-90265/home/6852893',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 391000),
#   'city': 'Malibu'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,063 Sq. Ft.',
#   'price': '$775,000',
#   'address': '612 S Barrington Ave #313, Los Angeles, CA 90049',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/612-S-Barrington-Ave-90049/unit-313/home/6836695',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 392000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '952 Sq. Ft.',
#   'price': '$299,900',
#   'address': '830 W Maple St, Compton, CA 90220',
#   'link': 'https://www.redfin.com/CA/Compton/830-W-Maple-St-90220/home/7350927',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 392000),
#   'city': 'Compton'},
#  {'beds': '—Beds',
#   'baths': '—Baths',
#   'area': '—Sq. Ft.',
#   'price': '$3,450,000',
#   'address': '0 Blythedale Rd, Agoura Hills, CA 91301',
#   'link': 'https://www.redfin.com/CA/Agoura-Hills/Blythedale-Rd-91301/home/172528388',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 393000),
#   'city': 'Agoura Hills'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,605 Sq. Ft.',
#   'price': '$1,650,000',
#   'address': '4032 Via Pavion, Palos Verdes Estates, CA 90274',
#   'link': 'https://www.redfin.com/CA/Palos-Verdes-Estates/4032-Via-Pavion-90274/home/7722749',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 394000),
#   'city': 'Palos Verdes Estates'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '2,050 Sq. Ft.',
#   'price': '$975,000',
#   'address': '4326 Whitewood Ave, Long Beach, CA 90808',
#   'link': 'https://www.redfin.com/CA/Long-Beach/4326-Whitewood-Ave-90808/home/7560486',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 394000),
#   'city': 'Long Beach'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '1,800 Sq. Ft.',
#   'price': '$458,000',
#   'address': '4155 Baldwin Park Blvd Unit B, Baldwin Park, CA 91706',
#   'link': 'https://www.redfin.com/CA/Baldwin-Park/4155-Baldwin-Park-Blvd-91706/unit-B/home/21921001',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 395000),
#   'city': 'Baldwin Park'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,117 Sq. Ft.',
#   'price': '$495,000',
#   'address': '22963 Nadine Cir Unit B, Torrance, CA 90505',
#   'link': 'https://www.redfin.com/CA/Torrance/22963-Nadine-Cir-90505/unit-B/home/7658664',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 29, 395000),
#   'city': 'Torrance'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '984 Sq. Ft.',
#   'price': '$72,900',
#   'address': '21001 Plummer St #49, Chatsworth, CA 91311',
#   'link': 'https://www.redfin.com/CA/Chatsworth/21001-Plummer-St-91311/unit-49/home/172261368',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 910000),
#   'city': 'Chatsworth'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '3,091 Sq. Ft.',
#   'price': '$2,079,000',
#   'address': '4209 Saint Clair Ave, Studio City, CA 91604',
#   'link': 'https://www.redfin.com/CA/Studio-City/4209-St-Clair-Ave-91604/home/5234602',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 911000),
#   'city': 'Studio City'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '757 Sq. Ft.',
#   'price': '$429,900',
#   'address': '17748 Palo Verde Ave, Cerritos, CA 90703',
#   'link': 'https://www.redfin.com/CA/Cerritos/17748-Palo-Verde-Ave-90703/home/7473168',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 911000),
#   'city': 'Cerritos'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,504 Sq. Ft.',
#   'price': '$585,000',
#   'address': '8829 Laurel St, Bellflower, CA 90706',
#   'link': 'https://www.redfin.com/CA/Bellflower/8829-Laurel-St-90706/home/7504540',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 912000),
#   'city': 'Bellflower'},
#  {'beds': '3 Beds',
#   'baths': '2.75 Baths',
#   'area': '1,427 Sq. Ft.',
#   'price': '$969,000',
#   'address': '1400 S Catalina #303, Redondo Beach, CA 90277',
#   'link': 'https://www.redfin.com/CA/Redondo-Beach/1400-S-Catalina-Ave-90277/unit-303/home/7707080',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 912000),
#   'city': 'Redondo Beach'},
#  {'beds': '4 Beds',
#   'baths': '2 Baths',
#   'area': '2,243 Sq. Ft.',
#   'price': '$1,499,000',
#   'address': '15054 Sunstone Pl, Sherman Oaks, CA 91403',
#   'link': 'https://www.redfin.com/CA/Sherman-Oaks/15054-Sunstone-Pl-91403/home/4892036',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 913000),
#   'city': 'Sherman Oaks'},
#  {'beds': '4 Beds',
#   'baths': '3.5 Baths',
#   'area': '3,217 Sq. Ft.',
#   'price': '$1,199,000',
#   'address': '16741 Knollwood Dr, Granada Hills, CA 91344',
#   'link': 'https://www.redfin.com/CA/Granada-Hills/16741-Knollwood-Dr-91344/home/5577486',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 914000),
#   'city': 'Granada Hills'},
#  {'beds': '3 Beds',
#   'baths': '3.5 Baths',
#   'area': '2,908 Sq. Ft.',
#   'price': '$3,599,000',
#   'address': '2420 Mandeville Canyon Rd, Los Angeles, CA 90049',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/2420-Mandeville-Canyon-Rd-90049/home/6860209',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 914000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '1,821 Sq. Ft.',
#   'price': '$1,249,000',
#   'address': '4530 Emerald Way, Culver City, CA 90230',
#   'link': 'https://www.redfin.com/CA/Culver-City/4530-Emerald-Way-90230/unit-16/home/6724553',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 915000),
#   'city': 'Culver City'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '1,398 Sq. Ft.',
#   'price': '$1,190,000',
#   'address': '1217 24th St Unit B, Santa Monica, CA 90404',
#   'link': 'https://www.redfin.com/CA/Santa-Monica/1217-24th-St-90404/unit-B/home/6768262',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 916000),
#   'city': 'Santa Monica'},
#  {'beds': '3 Beds',
#   'baths': '1.5 Baths',
#   'area': '2,084 Sq. Ft.',
#   'price': '$580,000',
#   'address': '274 N Dominguez Pl, Azusa, CA 91702',
#   'link': 'https://www.redfin.com/CA/Azusa/274-N-Dominguez-Pl-91702/home/8017338',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 916000),
#   'city': 'Azusa'},
#  {'beds': '3 Beds',
#   'baths': '1.75 Baths',
#   'area': '2,076 Sq. Ft.',
#   'price': '$1,700,000',
#   'address': '24875 Mulholland, Calabasas, CA 91302',
#   'link': 'https://www.redfin.com/CA/Calabasas/24875-Mulholland-Hwy-91302/home/6853763',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 917000),
#   'city': 'Calabasas'},
#  {'beds': '2 Beds',
#   'baths': '2 Baths',
#   'area': '884 Sq. Ft.',
#   'price': '$329,999',
#   'address': '20134 Leadwell St #131, Winnetka, CA 91306',
#   'link': 'https://www.redfin.com/CA/Winnetka/20134-Leadwell-St-91306/unit-131/home/3754668',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 918000),
#   'city': 'Winnetka'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,144 Sq. Ft.',
#   'price': '$73,000',
#   'address': '18540 Soledad Canyon Rd Spc 21, Canyon Country, CA 91351',
#   'link': 'https://www.redfin.com/CA/Canyon-Country/18540-Soledad-Canyon-Rd-91351/unit-21/home/172527822',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 919000),
#   'city': 'Canyon Country'},
#  {'beds': '—Beds',
#   'baths': '—Baths',
#   'area': '—Sq. Ft.',
#   'price': '$550,000',
#   'address': '0 Easterly Ter, Los Angeles, CA 90026',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/N-Easterly-Ter-90026/home/22125947',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 919000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '817 Sq. Ft.',
#   'price': '$485,000',
#   'address': '509 Los Angeles Ave, Monrovia, CA 91016',
#   'link': 'https://www.redfin.com/CA/Monrovia/509-Los-Angeles-Ave-91016/home/7969570',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 920000),
#   'city': 'Monrovia'},
#  {'beds': '2 Beds',
#   'baths': '3 Baths',
#   'area': '2,200 Sq. Ft.',
#   'price': '$2,695,000',
#   'address': '900 W Olympic Blvd Unit 47F, Los Angeles, CA 90015',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/900-W-Olympic-Blvd-90015/unit-47F/home/45359109',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 920000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,191 Sq. Ft.',
#   'price': '$465,000',
#   'address': '3712 E Iva St, Compton, CA 90221',
#   'link': 'https://www.redfin.com/CA/Compton/3712-E-Iva-St-90221/home/7622831',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 921000),
#   'city': 'Compton'},
#  {'beds': '6 Beds',
#   'baths': '9 Baths',
#   'area': '11,106 Sq. Ft.',
#   'price': '$38,000,000',
#   'address': '1024 Ridgedale Dr, Beverly Hills, CA 90210',
#   'link': 'https://www.redfin.com/CA/Beverly-Hills/1024-Ridgedale-Dr-90210/home/6822631',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 921000),
#   'city': 'Beverly Hills'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,200 Sq. Ft.',
#   'price': '$599,900',
#   'address': '12138 Anderberg Ave, Downey, CA 90242',
#   'link': 'https://www.redfin.com/CA/Downey/12138-Anderberg-Ave-90242/home/7402543',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 922000),
#   'city': 'Downey'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '939 Sq. Ft.',
#   'price': '$385,000',
#   'address': '8615 Beverly Blvd #30, Pico Rivera, CA 90660',
#   'link': 'https://www.redfin.com/CA/Pico-Rivera/8615-Beverly-Blvd-90660/unit-30/home/6982630',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 35, 922000),
#   'city': 'Pico Rivera'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '873 Sq. Ft.',
#   'price': '$490,000',
#   'address': '7104 S Marina Pacifica Dr S, Long Beach, CA 90803',
#   'link': 'https://www.redfin.com/CA/Long-Beach/7104-Marina-Pacifica-Dr-S-90803/home/7591694',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 42, 501000),
#   'city': 'Long Beach'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,435 Sq. Ft.',
#   'price': '$1,890,000',
#   'address': '1121 S Oakland Ave, Pasadena, CA 91106',
#   'link': 'https://www.redfin.com/CA/Pasadena/1121-S-Oakland-Ave-91106/unit-8/home/7010727',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 42, 501000),
#   'city': 'Pasadena'},
#  {'beds': '3 Beds',
#   'baths': '4 Baths',
#   'area': '2,500 Sq. Ft.',
#   'price': '$2,595,000',
#   'address': '651 Mildred Ave, Venice, CA 90291',
#   'link': 'https://www.redfin.com/CA/Venice/651-Mildred-Ave-90291/home/6734950',
#   'time': datetime.datetime(2020, 7, 21, 4, 30, 42, 502000),
#   'city': 'Venice'},
#  {'beds': '4 Beds',
#   'baths': '3.5 Baths',
# ...
#  {'beds': '4 Beds',
#   'baths': '2.75 Baths',
#   'area': '2,435 Sq. Ft.',
#   'price': '$1,350,000',
#   'address': '5110 Milne Dr, Torrance, CA 90505',
#   'link': 'https://www.redfin.com/CA/Torrance/5110-Milne-Dr-90505/home/7717416',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 290000),
#   'city': 'Torrance'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '1,610 Sq. Ft.',
#   'price': '$795,000',
#   'address': '6754 Aldea Ave, Lake Balboa, CA 91406',
#   'link': 'https://www.redfin.com/CA/Van-Nuys/6754-Aldea-Ave-91406/home/4559152',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 291000),
#   'city': 'Lake Balboa'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '381 Sq. Ft.',
#   'price': '$299,999',
#   'address': '525 S Ardmore Ave #246, Los Angeles, CA 90020',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/525-S-Ardmore-Ave-90020/unit-246/home/7090206',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 292000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,881 Sq. Ft.',
#   'price': '$799,000',
#   'address': '2581 Arvia St #10, Los Angeles, CA 90065',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/2581-Arvia-St-90065/unit-10/home/99356398',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 294000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '2,178 Sq. Ft.',
#   'price': '$1,595,000',
#   'address': '1535 S Sierra Bonita Ave, Los Angeles, CA 90019',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1535-S-Sierra-Bonita-Ave-90019/home/6904503',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 295000),
#   'city': 'Los Angeles'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '728 Sq. Ft.',
#   'price': '$1,450,000',
#   'address': '1309 Arizona Ave, Santa Monica, CA 90404',
#   'link': 'https://www.redfin.com/CA/Santa-Monica/1309-Arizona-Ave-90404/home/6773689',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 296000),
#   'city': 'Santa Monica'},
#  {'beds': '7 Beds',
#   'baths': '5 Baths',
#   'area': '3,708 Sq. Ft.',
#   'price': '$1,098,000',
#   'address': '10238 Valley View Ave, Whittier, CA 90604',
#   'link': 'https://www.redfin.com/CA/Whittier/10238-Valley-View-Ave-90604/home/7817813',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 297000),
#   'city': 'Whittier'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,318 Sq. Ft.',
#   'price': '$568,777',
#   'address': '18745 La Guardia St, Rowland Heights, CA 91748',
#   'link': 'https://www.redfin.com/CA/Rowland-Heights/18745-La-Guardia-St-91748/home/7862789',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 298000),
#   'city': 'Rowland Heights'},
#  {'beds': '8 Beds',
#   'baths': '4 Baths',
#   'area': '2,444 Sq. Ft.',
#   'price': '$750,000',
#   'address': '156 W 73rd St, Los Angeles, CA 90003',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/156-W-73rd-St-90003/home/7290062',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 298000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,550 Sq. Ft.',
#   'price': '$789,000',
#   'address': '815 S Harvard Blvd #502, Los Angeles, CA 90005',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/815-Harvard-90005/unit-502/home/12420582',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 299000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '2,389 Sq. Ft.',
#   'price': '$8,750,000',
#   'address': '23006 Pacific Coast Hwy, Malibu, CA 90265',
#   'link': 'https://www.redfin.com/CA/Malibu/23006-Pacific-Coast-Hwy-90265/home/6853245',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 299000),
#   'city': 'Malibu'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '711 Sq. Ft.',
#   'price': '$352,000',
#   'address': '1302 W Park Western Dr #150, San Pedro, CA 90732',
#   'link': 'https://www.redfin.com/CA/San-Pedro/1302-W-Park-Western-Dr-90732/unit-150/home/7686258',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 300000),
#   'city': 'San Pedro'},
#  {'beds': '8 Beds',
#   'baths': '7 Baths',
#   'area': '3,444 Sq. Ft.',
#   'price': '$2,065,000',
#   'address': '3319 Berkeley Ave, Los Angeles, CA 90026',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/3319-Berkeley-Ave-90026/home/7058640',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 301000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '3 Baths',
#   'area': '1,930 Sq. Ft.',
#   'price': '$719,000',
#   'address': '20950 Oxnard St #53, Woodland Hills, CA 91367',
#   'link': 'https://www.redfin.com/CA/Woodland-Hills/20950-W-Oxnard-St-91367/unit-53/home/4022400',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 301000),
#   'city': 'Woodland Hills'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '1,564 Sq. Ft.',
#   'price': '$929,434',
#   'address': '637 Daniel Freeman Cir, Inglewood, CA 90301',
#   'link': 'https://www.redfin.com/CA/Inglewood/602-Daniel-Freeman-Cir-90301/home/172273648',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 5, 302000),
#   'city': 'Inglewood'},
#  {'beds': '6 Beds',
#   'baths': '3 Baths',
#   'area': '2,760 Sq. Ft.',
#   'price': '$1,599,000',
#   'address': '1226 S Hayworth Ave, Los Angeles, CA 90035',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1226-S-Hayworth-Ave-90035/home/6914140',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 108000),
#   'city': 'Los Angeles'},
#  {'beds': '4 Beds',
#   'baths': '2.75 Baths',
#   'area': '2,435 Sq. Ft.',
#   'price': '$1,350,000',
#   'address': '5110 Milne Dr, Torrance, CA 90505',
#   'link': 'https://www.redfin.com/CA/Torrance/5110-Milne-Dr-90505/home/7717416',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 108000),
#   'city': 'Torrance'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '1,610 Sq. Ft.',
#   'price': '$795,000',
#   'address': '6754 Aldea Ave, Lake Balboa, CA 91406',
#   'link': 'https://www.redfin.com/CA/Van-Nuys/6754-Aldea-Ave-91406/home/4559152',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 109000),
#   'city': 'Lake Balboa'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '381 Sq. Ft.',
#   'price': '$299,999',
#   'address': '525 S Ardmore Ave #246, Los Angeles, CA 90020',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/525-S-Ardmore-Ave-90020/unit-246/home/7090206',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 109000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,881 Sq. Ft.',
#   'price': '$799,000',
#   'address': '2581 Arvia St #10, Los Angeles, CA 90065',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/2581-Arvia-St-90065/unit-10/home/99356398',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 110000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '2,178 Sq. Ft.',
#   'price': '$1,595,000',
#   'address': '1535 S Sierra Bonita Ave, Los Angeles, CA 90019',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1535-S-Sierra-Bonita-Ave-90019/home/6904503',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 110000),
#   'city': 'Los Angeles'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '728 Sq. Ft.',
#   'price': '$1,450,000',
#   'address': '1309 Arizona Ave, Santa Monica, CA 90404',
#   'link': 'https://www.redfin.com/CA/Santa-Monica/1309-Arizona-Ave-90404/home/6773689',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 111000),
#   'city': 'Santa Monica'},
#  {'beds': '7 Beds',
#   'baths': '5 Baths',
#   'area': '3,708 Sq. Ft.',
#   'price': '$1,098,000',
#   'address': '10238 Valley View Ave, Whittier, CA 90604',
#   'link': 'https://www.redfin.com/CA/Whittier/10238-Valley-View-Ave-90604/home/7817813',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 111000),
#   'city': 'Whittier'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,318 Sq. Ft.',
#   'price': '$568,777',
#   'address': '18745 La Guardia St, Rowland Heights, CA 91748',
#   'link': 'https://www.redfin.com/CA/Rowland-Heights/18745-La-Guardia-St-91748/home/7862789',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 112000),
#   'city': 'Rowland Heights'},
#  {'beds': '8 Beds',
#   'baths': '4 Baths',
#   'area': '2,444 Sq. Ft.',
#   'price': '$750,000',
#   'address': '156 W 73rd St, Los Angeles, CA 90003',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/156-W-73rd-St-90003/home/7290062',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 113000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,550 Sq. Ft.',
#   'price': '$789,000',
#   'address': '815 S Harvard Blvd #502, Los Angeles, CA 90005',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/815-Harvard-90005/unit-502/home/12420582',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 113000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '2,389 Sq. Ft.',
#   'price': '$8,750,000',
#   'address': '23006 Pacific Coast Hwy, Malibu, CA 90265',
#   'link': 'https://www.redfin.com/CA/Malibu/23006-Pacific-Coast-Hwy-90265/home/6853245',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 114000),
#   'city': 'Malibu'},
#  {'beds': '1 Bed',
#   'baths': '1 Bath',
#   'area': '711 Sq. Ft.',
#   'price': '$352,000',
#   'address': '1302 W Park Western Dr #150, San Pedro, CA 90732',
#   'link': 'https://www.redfin.com/CA/San-Pedro/1302-W-Park-Western-Dr-90732/unit-150/home/7686258',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 114000),
#   'city': 'San Pedro'},
#  {'beds': '8 Beds',
#   'baths': '7 Baths',
#   'area': '3,444 Sq. Ft.',
#   'price': '$2,065,000',
#   'address': '3319 Berkeley Ave, Los Angeles, CA 90026',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/3319-Berkeley-Ave-90026/home/7058640',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 115000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '3 Baths',
#   'area': '1,930 Sq. Ft.',
#   'price': '$719,000',
#   'address': '20950 Oxnard St #53, Woodland Hills, CA 91367',
#   'link': 'https://www.redfin.com/CA/Woodland-Hills/20950-W-Oxnard-St-91367/unit-53/home/4022400',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 115000),
#   'city': 'Woodland Hills'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '1,564 Sq. Ft.',
#   'price': '$929,434',
#   'address': '637 Daniel Freeman Cir, Inglewood, CA 90301',
#   'link': 'https://www.redfin.com/CA/Inglewood/602-Daniel-Freeman-Cir-90301/home/172273648',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 116000),
#   'city': 'Inglewood'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '843 Sq. Ft.',
#   'price': '$509,000',
#   'address': '1633 Bunker Ave, South El Monte, CA 91733',
#   'link': 'https://www.redfin.com/CA/El-Monte/1633-Bunker-Ave-91733/home/7799312',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 116000),
#   'city': 'South El Monte'},
#  {'beds': '3 Beds',
#   'baths': '1 Bath',
#   'area': '997 Sq. Ft.',
#   'price': '$185,000',
#   'address': '2011 W Newgrove St, Lancaster, CA 93536',
#   'link': 'https://www.redfin.com/CA/Lancaster/2011-W-Newgrove-St-93536/home/6291036',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 118000),
#   'city': 'Lancaster'},
#  {'beds': '—Beds',
#   'baths': '1 Bath',
#   'area': '534 Sq. Ft.',
#   'price': '$499,999',
#   'address': '960 Larrabee St #228, West Hollywood, CA 90069',
#   'link': 'https://www.redfin.com/CA/West-Hollywood/960-Larrabee-St-90069/unit-228/home/6817965',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 118000),
#   'city': 'West Hollywood'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,725 Sq. Ft.',
#   'price': '$1,799,000',
#   'address': '8918 Wonderland Park Ave, Los Angeles, CA 90046',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/8918-Wonderland-Park-Ave-90046/home/7123346',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 13, 119000),
#   'city': 'Los Angeles'},
#  {'beds': '2 Beds',
#   'baths': '1 Bath',
#   'area': '843 Sq. Ft.',
#   'price': '$509,000',
#   'address': '1633 Bunker Ave, South El Monte, CA 91733',
#   'link': 'https://www.redfin.com/CA/El-Monte/1633-Bunker-Ave-91733/home/7799312',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 37000),
#   'city': 'South El Monte'},
#  {'beds': '3 Beds',
#   'baths': '1 Bath',
#   'area': '997 Sq. Ft.',
#   'price': '$185,000',
#   'address': '2011 W Newgrove St, Lancaster, CA 93536',
#   'link': 'https://www.redfin.com/CA/Lancaster/2011-W-Newgrove-St-93536/home/6291036',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 38000),
#   'city': 'Lancaster'},
#  {'beds': '—Beds',
#   'baths': '1 Bath',
#   'area': '534 Sq. Ft.',
#   'price': '$499,999',
#   'address': '960 Larrabee St #228, West Hollywood, CA 90069',
#   'link': 'https://www.redfin.com/CA/West-Hollywood/960-Larrabee-St-90069/unit-228/home/6817965',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 38000),
#   'city': 'West Hollywood'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '1,725 Sq. Ft.',
#   'price': '$1,799,000',
#   'address': '8918 Wonderland Park Ave, Los Angeles, CA 90046',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/8918-Wonderland-Park-Ave-90046/home/7123346',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 39000),
#   'city': 'Los Angeles'},
#  {'beds': '3 Beds',
#   'baths': '3 Baths',
#   'area': '3,101 Sq. Ft.',
#   'price': '$3,695,000',
#   'address': '1564 Sunset Plaza Dr, West Hollywood, CA 90069',
#   'link': 'https://www.redfin.com/CA/Los-Angeles/1564-Sunset-Plaza-Dr-90069/home/7119968',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 40000),
#   'city': 'West Hollywood'},
#  {'beds': '4 Beds',
#   'baths': '2.5 Baths',
#   'area': '2,074 Sq. Ft.',
#   'price': '$774,888',
#   'address': '24317 Darrin Dr, Diamond Bar, CA 91765',
#   'link': 'https://www.redfin.com/CA/Diamond-Bar/24317-Darrin-Dr-91765/home/7874393',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 40000),
#   'city': 'Diamond Bar'},
#  {'beds': '—Beds',
#   'baths': '—Baths',
#   'area': '—Sq. Ft.',
#   'price': '$280,000',
#   'address': '31 Vac Vic Shannon Valley Rd, Acton, CA 93510',
#   'link': 'https://www.redfin.com/CA/Acton/31-Shannon-Valley-Rd-93510/home/28508958',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 41000),
#   'city': 'Acton'},
#  {'beds': '3 Beds',
#   'baths': '2.5 Baths',
#   'area': '2,141 Sq. Ft.',
#   'price': '$1,148,800',
#   'address': '1626 Ina Dr, Glendale, CA 91206',
#   'link': 'https://www.redfin.com/CA/Glendale/1626-Ina-Dr-91206/home/7170514',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 42000),
#   'city': 'Glendale'},
#  {'beds': '8 Beds',
#   'baths': '5 Baths',
#   'area': '4,413 Sq. Ft.',
#   'price': '$1,750,000',
#   'address': '1110 Leland Way, Burbank, CA 91504',
#   'link': 'https://www.redfin.com/CA/Burbank/1110-Leland-Way-91504/home/5355957',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 42000),
#   'city': 'Burbank'},
#  {'beds': '4 Beds',
#   'baths': '3.5 Baths',
#   'area': '2,307 Sq. Ft.',
#   'price': '$649,999',
#   'address': '21037 Ingomar St, Canoga Park, CA 91304',
#   'link': 'https://www.redfin.com/CA/Canoga-Park/21037-Ingomar-St-91304/home/3709666',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 43000),
#   'city': 'Canoga Park'},
#  {'beds': '5 Beds',
#   'baths': '4 Baths',
#   'area': '1,780 Sq. Ft.',
#   'price': '$574,500',
#   'address': '13240 Betz Blvd, Sylmar, CA 91342',
#   'link': 'https://www.redfin.com/CA/Sylmar/13240-Betz-Blvd-91342/home/146020684',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 44000),
#   'city': 'Sylmar'},
#  {'beds': '4 Beds',
#   'baths': '3 Baths',
#   'area': '2,557 Sq. Ft.',
#   'price': '$799,900',
#   'address': '15417 Olive Branch Dr, La Mirada, CA 90638',
#   'link': 'https://www.redfin.com/CA/La-Mirada/15417-Olive-Branch-Dr-90638/home/7769776',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 44000),
#   'city': 'La Mirada'},
#  {'beds': '3 Beds',
#   'baths': '2 Baths',
#   'area': '1,104 Sq. Ft.',
#   'price': '$539,999',
#   'address': '8124 Greenvale Ave, Pico Rivera, CA 90660',
#   'link': 'https://www.redfin.com/CA/Pico-Rivera/8124-Greenvale-Ave-90660/home/7454702',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 45000),
#   'city': 'Pico Rivera'},
#  {'beds': '4 Beds',
#   'baths': '2 Baths',
#   'area': '1,903 Sq. Ft.',
#   'price': '$1,800,000',
#   'address': '10739 Northgate St, Culver City, CA 90230',
#   'link': 'https://www.redfin.com/CA/Culver-City/10739-Northgate-St-90230/home/6719326',
#   'time': datetime.datetime(2020, 7, 28, 9, 45, 21, 46000),
#   'city': 'Culver City'}]

# %%
test = {
    "test":1,
    "test1":2
}
test
# Out:
# {'test': 1, 'test1': 2}

# %%
# Out:
# ['test', 'test1']
